# %% [markdown]
# ## Creating Functions for the model analysis

# %%
def clean_join_model(a:str, b): 
    df_join_model = clean_model_fuel(a, b).merge(clean_model_state(a, b), on='model')
    return df_join_model

# %%
# Displaying up to 100 columns
pd.set_option('display.max_columns', 100)

# %%
from table_function import clean_join_model_default
df_model_analysis = clean_join_model_default()
df_model_analysis
# Out:
#      manufacturer_x     model  tsn  power_kw fuel_type drive_type body_type  \
# 0               BMW    i3s,i3  BSI      75.0         E        NaN
# 1               BMW    i3s,i3  BSI      75.0         E        NaN
# 2               BMW    i3s,i3  BSI      75.0         E        NaN
# 3               BMW    i3s,i3  BSI      75.0         E        NaN
# 4               BMW    i3s,i3  BSI      75.0         E        NaN
# ...             ...       ...  ...       ...       ...        ...       ...
# 2222      VOLVO (S)  XC40,C40  BTE     160.0         E          A
# 2223      VOLVO (S)  XC40,C40  BTE     160.0         E          A
# 2224      VOLVO (S)  XC40,C40  BTE     160.0         E          A
# 2225      VOLVO (S)  XC40,C40  BTE     160.0         E          A
# 2226      VOLVO (S)  XC40,C40  BTE     160.0         E          A
#
#       total  motorhomes  private_owners  owners_under_29_years  \
# 0      2788           0            1120                     14
# 1      2788           0            1120                     14
# 2      2788           0            1120                     14
# 3      2788           0            1120                     14
# 4      2788           0            1120                     14
# ...     ...         ...             ...                    ...
# 2222   1217           0             262                      4
# 2223   1217           0             262                      4
# 2224   1217           0             262                      4
# 2225   1217           0             262                      4
# 2226   1217           0             262                      4
#
#       owners_over_60_years  female_owners  year_x manufacturer_y  year_y  \
# 0                      304            311    2017            BMW    2017
# 1                      304            311    2017            BMW    2017
# 2                      304            311    2017            BMW    2017
# 3                      304            311    2017            BMW    2017
# 4                      304            311    2017            BMW    2017
# ...                    ...            ...     ...            ...     ...
# 2222                   137             67    2021      VOLVO (S)    2021
# 2223                   137             67    2021      VOLVO (S)    2021
# 2224                   137             67    2021      VOLVO (S)    2021
# 2225                   137             67    2021      VOLVO (S)    2021
# 2226                   137             67    2021      VOLVO (S)    2021
#
#            federal_state  new_registration
# 0      Baden-Württemberg               471
# 1                 Bayern              1024
# 2                 Berlin               101
# 3            Brandenburg                56
# 4                 Bremen                 9
# ...                  ...               ...
# 2222             Sachsen                12
# 2223      Sachsen-Anhalt                 6
# 2224  Schleswig-Holstein                45
# 2225           Thüringen                 7
# 2226             special                 0
#
# [5406 rows x 18 columns]

# %%
df_model_analysis.columns
# Out:
# Index(['manufacturer_x', 'model', 'tsn', 'power_kw', 'fuel_type', 'drive_type',
#        'body_type', 'total', 'motorhomes', 'private_owners',
#        'owners_under_29_years', 'owners_over_60_years', 'female_owners',
#        'year_x', 'manufacturer_y', 'year_y', 'federal_state',
#        'new_registration'],
#       dtype='object')

# %%
df_model_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5406 entries, 0 to 2226
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   manufacturer_x         5406 non-null   object
#  1   model                  5406 non-null   object
#  2   tsn                    5406 non-null   object
#  3   power_kw               5406 non-null   float64
#  4   fuel_type              5406 non-null   object
#  5   drive_type             4114 non-null   object
#  6   body_type              4165 non-null   object
#  7   total                  5406 non-null   int64
#  8   motorhomes             5406 non-null   int64
#  9   private_owners         5406 non-null   int64
#  10  owners_under_29_years  5406 non-null   int64
#  11  owners_over_60_years   5406 non-null   int64
#  12  female_owners          5406 non-null   int64
#  13  year_x                 5406 non-null   int64
#  14  manufacturer_y         5406 non-null   object
#  15  year_y                 5406 non-null   int64
#  16  federal_state          5406 non-null   object
#  17  new_registration       5406 non-null   int64
# dtypes: float64(1), int64(9), object(8)
# memory usage: 802.5+ KB

# %%
df_model_analysis.drop(['manufacturer_y', 'year_y', 'motorhomes', 'drive_type', 'body_type'], axis=1, inplace=True)

# %%
df_model_analysis.head(1)
# Out:
#   manufacturer_x   model  tsn  power_kw fuel_type  total  private_owners  \
# 0            BMW  i3s,i3  BSI      75.0         E   2788            1120
#
#    owners_under_29_years  owners_over_60_years  female_owners  year_x  \
# 0                     14                   304            311    2017
#
#        federal_state  new_registration
# 0  Baden-Württemberg               471

# %%
df_model_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5406 entries, 0 to 2226
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   manufacturer_x         5406 non-null   object
#  1   model                  5406 non-null   object
#  2   tsn                    5406 non-null   object
#  3   power_kw               5406 non-null   float64
#  4   fuel_type              5406 non-null   object
#  5   total                  5406 non-null   int64
#  6   private_owners         5406 non-null   int64
#  7   owners_under_29_years  5406 non-null   int64
#  8   owners_over_60_years   5406 non-null   int64
#  9   female_owners          5406 non-null   int64
#  10  year_x                 5406 non-null   int64
#  11  federal_state          5406 non-null   object
#  12  new_registration       5406 non-null   int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 591.3+ KB

# %%
# Saving the df as a csv file in this Repo on GitHub 
df_model_analysis.to_csv('model_analysis_clean.csv', index=False)
